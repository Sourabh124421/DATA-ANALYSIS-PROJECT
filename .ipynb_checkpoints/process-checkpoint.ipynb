# %%
import csv

def read_csv_file():
    file_path = input("Enter FILE PATH : ")
    try:
        with open(file_path, encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile)
            data = [row for row in reader]
            return data, file_path
    except FileNotFoundError:
        print(f"Error: File not found: {file_path}")
        return [], file_path
    except:
        print(f"Error: Could not read file: {file_path}")
        return [], file_path

def retrieve_host_data(data):
    if not data:
        print("Error: No data found.")
        return
    # To retrieve the data from the dataset we need to create a new dict
    data_dict = {}
    for row in data:
        host_id = row['host_id']
        data_dict[host_id] = row

    # Take input from user for hostID
    host_id = input("Enter the host ID to retrieve data for: ")

    # Data to be accessed for the respective hostID using if else condition 
    if host_id in data_dict:
        host_data = data_dict[host_id]
        name = host_data['name']
        host_name = host_data['host_name']
        description = host_data['description']
        host_location = host_data['host_location']
        created_date = host_data['host_since']
        # Print all the data about the host ID
        print(f"Name of listing: {name}\nHost name: {host_name}\nDescription: {description}\nHost location: {host_location}\nCreated date: {created_date}")
    else:
        # Print message to be displayed if hostID is not found 
        print(f"Sorry! No Data found regarding HostID:{host_id}")

def filter_by_location(file_path):
    # Take input from user for location
    location = input("What location are you looking for?: ")

    # Open the CSV file
    with open(file_path, encoding='utf-8') as csv_file:
        reader = csv.DictReader(csv_file)
        filtered_data = []
        for row in reader:
            if row['host_location'] == location:
                filtered_data.append({'host_name': row['host_name'], 'property_type': row['property_type'], 'price': row['price'], 'minimum_nights': row['minimum_nights'], 'maximum_nights': row['maximum_nights']})

    # Print the filtered data
    print("Here is the data you requested for -")
    for row in filtered_data:
        print(row)

def filter_by_property_type(file_path):
    # Take input from user for property type
    property_type = input('What Kind Of Property Are You Looking For ? -\n -renatl unit \n -Private room \n -houseboat \n -townhouse \n -home \n -condo \n -loft \n -cottage \n -guest suite \n -boat \n -cabin \n -serviced apartment \n -bed and breakfast \n -')
    
    # Open the CSV file
    with open(file_path, encoding='utf-8') as csv_file:
        reader = csv.DictReader(csv_file)
        filtered_data = []
        for row in reader:
            if row['property_type'] == property_type:
                filtered_data.append({'room_type': row['room_type'], 'accommodates': row['accommodates'], 'bathrooms': row['bathrooms_text'], 'bedrooms': row['bedrooms'], 'beds': row['beds']})

    # Print the filtered data
    print("Here is the data you requested for -")
    for row in filtered_data:
        print(row)

def filter_by_host_location(file_path, location, host_name):
    location = input('Please provide a location:')
    host_name = input('Please Input a Name:')
    try:
        with open(file_path, encoding='utf-8') as file:
            reader = csv.DictReader(file)
            filtered_data = []

            for row in reader:
                if row['host_location'] == location and row['host_name'] == host_name:
                    filtered_data.append({'acceptance_rate': row['host_acceptance_rate'], 'amenities': row['amenities'], 'instant_bookable': row['instant_bookable']})

            print(f"Here is the data you requested for {host_name} for his property at {location}")
            for data in filtered_data:
                print(data)
        return filtered_data
    except FileNotFoundError:
        print(f"Error: File not found: {file_path}")
        return []
    except:
        print(f"Error: Could not read file: {file_path}")
        return []

    
#CSV file data and file path using read_csv_file() function
data, file_path = read_csv_file()

# retrieve_host_data() function
retrieve_host_data(data)

#filter data by location using filter_by_location() function
filter_by_location(file_path)

#filter data by property type using filter_by_property_type function
filter_by_property_type(file_path)

#filter by host location using filter_by_host_location function
filter_by_host_location(file_path, "location", "host_name")

# # CSV file data and file path using read_csv_file() function
# data = read_csv_file(file_path)

# # retrieve_host_data() function
# retrieve_host_data(file_path)

# #filter data by location using filter_by_location() function
# filter_by_location(file_path)

# #filter data by property type using filter_by_property_type function
# filter_by_property_type(file_path)

# #filter by host location using filter_by_host_location function
# filter_by_host_location(file_path)
# Out:
# Enter FILE PATH : C:\Users\Sourabh\Desktop\com728\Airbnb_UK_2022.csv
# Enter the host ID to retrieve data for: 182322
# Name of listing: Room with a view  zone 1  Central Bankside
# Host name: Nina
# Description: a luminous room in a modern   bed and breakfastroom flat located in central london  room has a great view of shard building and is very light  simply furnished with neutral minimal decor this listing is a for a separate isolated bed and breakfastroom   the bathroom is shared  the kitchen area can be used moderately   but not before  am or after  pm  the flat is shared with only one person  vegetarian household the spacethis listing is a for a separate isolated bed and breakfastroom   the bathroom is shared  the kitchen area can be used moderately   but not before  am or after  pm  vegetarian household  the room is filled with light  and has a great view of shard  windows are large  there is a king size bed and breakfast  clothes rail  small computer table and a chair  the room has wooden floors and is decorated in neutral tones  the room would suit someone who is in london on a short visit on work  business trip and would need a calm safe
# Host location: London
# Created date: 27-07-10
# What location are you looking for?: London
# Here is the data you requested for -
# {'host_name': 'Meg', 'property_type': 'houseboat', 'price': '204', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Tania', 'property_type': 'rental unit', 'price': '297', 'minimum_nights': '14', 'maximum_nights': '365'}
# {'host_name': 'Joe', 'property_type': 'townhouse', 'price': '195', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Joe', 'property_type': 'townhouse', 'price': '30', 'minimum_nights': '7', 'maximum_nights': '730'}
# {'host_name': 'Olga', 'property_type': 'rental unit', 'price': '136', 'minimum_nights': '5', 'maximum_nights': '90'}
# {'host_name': 'Matt', 'property_type': 'rental unit', 'price': '29', 'minimum_nights': '2', 'maximum_nights': '31'}
# {'host_name': 'Clare', 'property_type': 'rental unit', 'price': '180', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Milena', 'property_type': 'rental unit', 'price': '120', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Gill', 'property_type': 'rental unit', 'price': '40', 'minimum_nights': '2', 'maximum_nights': '7'}
# {'host_name': 'Rita', 'property_type': 'rental unit', 'price': '207', 'minimum_nights': '3', 'maximum_nights': '21'}
# {'host_name': 'Nina', 'property_type': 'rental unit', 'price': '95', 'minimum_nights': '2', 'maximum_nights': '365'}
# {'host_name': 'Eilinn', 'property_type': 'townhouse', 'price': '90', 'minimum_nights': '4', 'maximum_nights': '21'}
# {'host_name': 'Calypso', 'property_type': 'rental unit', 'price': '140', 'minimum_nights': '4', 'maximum_nights': '30'}
# {'host_name': 'Nathan', 'property_type': 'rental unit', 'price': '100', 'minimum_nights': '1', 'maximum_nights': '14'}
# {'host_name': 'Mark', 'property_type': 'condo', 'price': '88', 'minimum_nights': '1', 'maximum_nights': '90'}
# {'host_name': 'Deb', 'property_type': 'condo', 'price': '45', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Alexandra', 'property_type': 'rental unit', 'price': '160', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Yael', 'property_type': 'rental unit', 'price': '400', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Let S Dance  Put On Your Red Shoes', 'property_type': 'rental unit', 'price': '48', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Eliza', 'property_type': 'rental unit', 'price': '199', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Maria', 'property_type': 'townhouse', 'price': '300', 'minimum_nights': '3', 'maximum_nights': '90'}
# {'host_name': 'Robert And Antonio', 'property_type': 'townhouse', 'price': '36', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Heather', 'property_type': 'home', 'price': '60', 'minimum_nights': '1', 'maximum_nights': '30'}
# {'host_name': 'Kyri', 'property_type': 'condo', 'price': '92', 'minimum_nights': '2', 'maximum_nights': '45'}
# {'host_name': 'Vee', 'property_type': 'rental unit', 'price': '85', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Sara', 'property_type': 'rental unit', 'price': '240', 'minimum_nights': '4', 'maximum_nights': '365'}
# {'host_name': 'Alda', 'property_type': 'rental unit', 'price': '53', 'minimum_nights': '3', 'maximum_nights': '730'}
# {'host_name': 'Lara', 'property_type': 'home', 'price': '97', 'minimum_nights': '7', 'maximum_nights': '28'}
# {'host_name': 'Radhika And Lorenzo', 'property_type': 'rental unit', 'price': '40', 'minimum_nights': '10', 'maximum_nights': '1125'}
# {'host_name': 'Mirjam', 'property_type': 'home', 'price': '29', 'minimum_nights': '2', 'maximum_nights': '200'}
# {'host_name': 'Toni', 'property_type': 'rental unit', 'price': '97', 'minimum_nights': '4', 'maximum_nights': '1120'}
# {'host_name': 'Anna', 'property_type': 'condo', 'price': '77', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Emi', 'property_type': 'rental unit', 'price': '120', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Eleni   Tom', 'property_type': 'rental unit', 'price': '120', 'minimum_nights': '7', 'maximum_nights': '50'}
# {'host_name': 'Stephen', 'property_type': 'home', 'price': '863', 'minimum_nights': '14', 'maximum_nights': '30'}
# {'host_name': 'Ungelie', 'property_type': 'rental unit', 'price': '90', 'minimum_nights': '1', 'maximum_nights': '13'}
# {'host_name': 'Janina', 'property_type': 'home', 'price': '48', 'minimum_nights': '20', 'maximum_nights': '365'}
# {'host_name': 'Dusan', 'property_type': 'condo', 'price': '369', 'minimum_nights': '2', 'maximum_nights': '4'}
# {'host_name': 'Dalston', 'property_type': 'rental unit', 'price': '75', 'minimum_nights': '1', 'maximum_nights': '365'}
# {'host_name': 'Katherine', 'property_type': 'rental unit', 'price': '120', 'minimum_nights': '6', 'maximum_nights': '365'}
# {'host_name': 'Mojdeh', 'property_type': 'rental unit', 'price': '95', 'minimum_nights': '3', 'maximum_nights': '90'}
# {'host_name': 'Gill', 'property_type': 'home', 'price': '36', 'minimum_nights': '2', 'maximum_nights': '28'}
# {'host_name': 'Elaine', 'property_type': 'rental unit', 'price': '40', 'minimum_nights': '3', 'maximum_nights': '60'}
# {'host_name': 'Kenichiro', 'property_type': 'rental unit', 'price': '59', 'minimum_nights': '2', 'maximum_nights': '60'}
# {'host_name': 'Clare', 'property_type': 'townhouse', 'price': '45', 'minimum_nights': '3', 'maximum_nights': '120'}
# {'host_name': 'Murielle', 'property_type': 'rental unit', 'price': '41', 'minimum_nights': '3', 'maximum_nights': '7'}
# {'host_name': 'Elisabetta', 'property_type': 'home', 'price': '65', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Amy  Gabriella', 'property_type': 'rental unit', 'price': '135', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Kadija', 'property_type': 'rental unit', 'price': '50', 'minimum_nights': '5', 'maximum_nights': '365'}
# {'host_name': 'Rachel', 'property_type': 'home', 'price': '60', 'minimum_nights': '2', 'maximum_nights': '90'}
# {'host_name': 'Tina', 'property_type': 'home', 'price': '38', 'minimum_nights': '1', 'maximum_nights': '28'}
# {'host_name': 'Clare', 'property_type': 'rental unit', 'price': '99', 'minimum_nights': '4', 'maximum_nights': '31'}
# {'host_name': 'Julia', 'property_type': 'rental unit', 'price': '270', 'minimum_nights': '5', 'maximum_nights': '365'}
# {'host_name': 'Kinga', 'property_type': 'rental unit', 'price': '99', 'minimum_nights': '12', 'maximum_nights': '89'}
# {'host_name': 'Natalie', 'property_type': 'condo', 'price': '99', 'minimum_nights': '6', 'maximum_nights': '20'}
# {'host_name': 'Tom', 'property_type': 'condo', 'price': '149', 'minimum_nights': '3', 'maximum_nights': '1124'}
# {'host_name': 'Steven', 'property_type': 'home', 'price': '120', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Dee Dee', 'property_type': 'rental unit', 'price': '42', 'minimum_nights': '2', 'maximum_nights': '730'}
# {'host_name': 'Sarah', 'property_type': 'rental unit', 'price': '100', 'minimum_nights': '3', 'maximum_nights': '120'}
# {'host_name': 'Arnie', 'property_type': 'rental unit', 'price': '120', 'minimum_nights': '1', 'maximum_nights': '1124'}
# {'host_name': 'Darshi Rowan And Tara', 'property_type': 'rental unit', 'price': '336', 'minimum_nights': '5', 'maximum_nights': '365'}
# {'host_name': 'Hilda', 'property_type': 'rental unit', 'price': '32', 'minimum_nights': '2', 'maximum_nights': '14'}
# {'host_name': 'Aneta', 'property_type': 'condo', 'price': '46', 'minimum_nights': '3', 'maximum_nights': '180'}
# {'host_name': 'Emma', 'property_type': 'rental unit', 'price': '75', 'minimum_nights': '4', 'maximum_nights': '9011'}
# {'host_name': 'Eleonor', 'property_type': 'rental unit', 'price': '200', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Cryn', 'property_type': 'townhouse', 'price': '28', 'minimum_nights': '1', 'maximum_nights': '21'}
# {'host_name': 'Maria', 'property_type': 'condo', 'price': '160', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Frankie', 'property_type': 'rental unit', 'price': '150', 'minimum_nights': '4', 'maximum_nights': '30'}
# {'host_name': 'Orsi', 'property_type': 'rental unit', 'price': '26', 'minimum_nights': '1', 'maximum_nights': '31'}
# {'host_name': 'Sandy', 'property_type': 'rental unit', 'price': '97', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Marsha', 'property_type': 'rental unit', 'price': '101', 'minimum_nights': '7', 'maximum_nights': '1125'}
# {'host_name': 'D   D', 'property_type': 'rental unit', 'price': '98', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Mary', 'property_type': 'rental unit', 'price': '91', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Vicky', 'property_type': 'home', 'price': '65', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Marianne', 'property_type': 'rental unit', 'price': '114', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Suzanne', 'property_type': 'home', 'price': '49', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Alicia', 'property_type': 'rental unit', 'price': '110', 'minimum_nights': '7', 'maximum_nights': '1125'}
# {'host_name': 'London', 'property_type': 'rental unit', 'price': '117', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Brendan', 'property_type': 'rental unit', 'price': '40', 'minimum_nights': '3', 'maximum_nights': '21'}
# {'host_name': 'Arvind', 'property_type': 'rental unit', 'price': '500', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Laura', 'property_type': 'condo', 'price': '85', 'minimum_nights': '5', 'maximum_nights': '14'}
# {'host_name': 'Jenny', 'property_type': 'rental unit', 'price': '52', 'minimum_nights': '6', 'maximum_nights': '1125'}
# {'host_name': 'Hazel', 'property_type': 'rental unit', 'price': '155', 'minimum_nights': '3', 'maximum_nights': '32'}
# {'host_name': 'Lia', 'property_type': 'home', 'price': '413', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'John And Sarah', 'property_type': 'home', 'price': '65', 'minimum_nights': '1', 'maximum_nights': '7'}
# {'host_name': 'Adriana', 'property_type': 'rental unit', 'price': '28', 'minimum_nights': '7', 'maximum_nights': '30'}
# {'host_name': 'Simon', 'property_type': 'rental unit', 'price': '72', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Jonathan', 'property_type': 'rental unit', 'price': '120', 'minimum_nights': '2', 'maximum_nights': '10'}
# {'host_name': 'Alec', 'property_type': 'rental unit', 'price': '30', 'minimum_nights': '3', 'maximum_nights': '5'}
# {'host_name': 'Nynke', 'property_type': 'rental unit', 'price': '75', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Andr ', 'property_type': 'rental unit', 'price': '180', 'minimum_nights': '4', 'maximum_nights': '30'}
# {'host_name': 'Susan', 'property_type': 'home', 'price': '40', 'minimum_nights': '3', 'maximum_nights': '15'}
# {'host_name': 'Graham   Ivano', 'property_type': 'home', 'price': '100', 'minimum_nights': '7', 'maximum_nights': '18'}
# {'host_name': 'Claudius', 'property_type': 'rental unit', 'price': '279', 'minimum_nights': '6', 'maximum_nights': '1125'}
# {'host_name': 'Nicki', 'property_type': 'rental unit', 'price': '55', 'minimum_nights': '13', 'maximum_nights': '100'}
# {'host_name': 'Carmen', 'property_type': 'condo', 'price': '60', 'minimum_nights': '7', 'maximum_nights': '60'}
# {'host_name': 'Andrew', 'property_type': 'condo', 'price': '99', 'minimum_nights': '7', 'maximum_nights': '10'}
# {'host_name': 'Geraldine', 'property_type': 'home', 'price': '23', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Colin', 'property_type': 'rental unit', 'price': '12', 'minimum_nights': '30', 'maximum_nights': '60'}
# {'host_name': 'Philip', 'property_type': 'condo', 'price': '31', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'David', 'property_type': 'townhouse', 'price': '82', 'minimum_nights': '2', 'maximum_nights': '31'}
# {'host_name': 'Raphael', 'property_type': 'home', 'price': '48', 'minimum_nights': '2', 'maximum_nights': '5'}
# {'host_name': 'Maryam', 'property_type': 'rental unit', 'price': '115', 'minimum_nights': '10', 'maximum_nights': '1124'}
# {'host_name': 'Alison', 'property_type': 'home', 'price': '35', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Jonathan', 'property_type': 'home', 'price': '52', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Judy', 'property_type': 'home', 'price': '51', 'minimum_nights': '5', 'maximum_nights': '28'}
# {'host_name': 'Larisa', 'property_type': 'rental unit', 'price': '210', 'minimum_nights': '30', 'maximum_nights': '1125'}
# {'host_name': 'Monica', 'property_type': 'home', 'price': '50', 'minimum_nights': '3', 'maximum_nights': '365'}
# {'host_name': 'Monique', 'property_type': 'townhouse', 'price': '35', 'minimum_nights': '1', 'maximum_nights': '31'}
# {'host_name': 'Jeanie', 'property_type': 'home', 'price': '55', 'minimum_nights': '1', 'maximum_nights': '30'}
# {'host_name': 'Eileen', 'property_type': 'rental unit', 'price': '50', 'minimum_nights': '5', 'maximum_nights': '60'}
# {'host_name': 'Richard', 'property_type': 'townhouse', 'price': '37', 'minimum_nights': '1', 'maximum_nights': '15'}
# {'host_name': 'Andrew', 'property_type': 'rental unit', 'price': '140', 'minimum_nights': '5', 'maximum_nights': '14'}
# {'host_name': 'Ali', 'property_type': 'home', 'price': '31', 'minimum_nights': '7', 'maximum_nights': '365'}
# {'host_name': 'Serge', 'property_type': 'townhouse', 'price': '60', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'James', 'property_type': 'home', 'price': '50', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Cheryl  Anna  Lee', 'property_type': 'rental unit', 'price': '125', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Martin', 'property_type': 'rental unit', 'price': '95', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Mayda', 'property_type': 'home', 'price': '65', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Tom', 'property_type': 'rental unit', 'price': '96', 'minimum_nights': '2', 'maximum_nights': '90'}
# {'host_name': 'Kevin', 'property_type': 'rental unit', 'price': '68', 'minimum_nights': '2', 'maximum_nights': '31'}
# {'host_name': 'Isabelle', 'property_type': 'townhouse', 'price': '30', 'minimum_nights': '2', 'maximum_nights': '10'}
# {'host_name': 'Esther', 'property_type': 'rental unit', 'price': '44', 'minimum_nights': '14', 'maximum_nights': '365'}
# {'host_name': 'Stephane', 'property_type': 'condo', 'price': '140', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Michelle', 'property_type': 'home', 'price': '399', 'minimum_nights': '2', 'maximum_nights': '21'}
# {'host_name': 'Mr NADORI', 'property_type': 'home', 'price': '40', 'minimum_nights': '5', 'maximum_nights': '365'}
# {'host_name': 'Antonello', 'property_type': 'rental unit', 'price': '257', 'minimum_nights': '6', 'maximum_nights': '31'}
# {'host_name': 'Dev', 'property_type': 'rental unit', 'price': '180', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Judith', 'property_type': 'home', 'price': '65', 'minimum_nights': '2', 'maximum_nights': '365'}
# {'host_name': 'Michael', 'property_type': 'rental unit', 'price': '99', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Caroline', 'property_type': 'home', 'price': '33', 'minimum_nights': '1', 'maximum_nights': '21'}
# {'host_name': 'Danna', 'property_type': 'rental unit', 'price': '58', 'minimum_nights': '2', 'maximum_nights': '10'}
# {'host_name': 'Natalie', 'property_type': 'home', 'price': '32', 'minimum_nights': '5', 'maximum_nights': '28'}
# {'host_name': 'Moira', 'property_type': 'townhouse', 'price': '46', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Claudia', 'property_type': 'rental unit', 'price': '52', 'minimum_nights': '3', 'maximum_nights': '50'}
# {'host_name': 'Wendy', 'property_type': 'rental unit', 'price': '35', 'minimum_nights': '3', 'maximum_nights': '30'}
# {'host_name': 'Tea', 'property_type': 'home', 'price': '149', 'minimum_nights': '2', 'maximum_nights': '35'}
# {'host_name': 'Violeta', 'property_type': 'condo', 'price': '109', 'minimum_nights': '7', 'maximum_nights': '30'}
# {'host_name': 'Lucas', 'property_type': 'home', 'price': '80', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Jose And Teresa', 'property_type': 'home', 'price': '52', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Violetta', 'property_type': 'condo', 'price': '96', 'minimum_nights': '8', 'maximum_nights': '120'}
# {'host_name': 'Edson', 'property_type': 'rental unit', 'price': '100', 'minimum_nights': '21', 'maximum_nights': '1125'}
# {'host_name': 'Mikail', 'property_type': 'home', 'price': '400', 'minimum_nights': '6', 'maximum_nights': '40'}
# {'host_name': 'Dieter', 'property_type': 'rental unit', 'price': '125', 'minimum_nights': '7', 'maximum_nights': '45'}
# {'host_name': 'Riccardo', 'property_type': 'rental unit', 'price': '133', 'minimum_nights': '2', 'maximum_nights': '60'}
# {'host_name': 'Manfredi', 'property_type': 'rental unit', 'price': '180', 'minimum_nights': '14', 'maximum_nights': '45'}
# {'host_name': 'Joseph', 'property_type': 'rental unit', 'price': '53', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Veri', 'property_type': 'rental unit', 'price': '118', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Kasia', 'property_type': 'rental unit', 'price': '210', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Lala', 'property_type': 'rental unit', 'price': '100', 'minimum_nights': '4', 'maximum_nights': '8'}
# {'host_name': 'Michele', 'property_type': 'rental unit', 'price': '100', 'minimum_nights': '14', 'maximum_nights': '90'}
# {'host_name': 'Stefania', 'property_type': 'home', 'price': '45', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Dominic', 'property_type': 'rental unit', 'price': '105', 'minimum_nights': '4', 'maximum_nights': '21'}
# {'host_name': 'Mandeep', 'property_type': 'cabin', 'price': '51', 'minimum_nights': '1', 'maximum_nights': '30'}
# {'host_name': 'Geraldine', 'property_type': 'rental unit', 'price': '105', 'minimum_nights': '5', 'maximum_nights': '15'}
# {'host_name': 'Patsy', 'property_type': 'rental unit', 'price': '40', 'minimum_nights': '3', 'maximum_nights': '21'}
# {'host_name': 'Mark', 'property_type': 'rental unit', 'price': '140', 'minimum_nights': '90', 'maximum_nights': '90'}
# {'host_name': 'Joel', 'property_type': 'rental unit', 'price': '455', 'minimum_nights': '7', 'maximum_nights': '365'}
# {'host_name': 'Carolyn', 'property_type': 'condo', 'price': '70', 'minimum_nights': '7', 'maximum_nights': '62'}
# {'host_name': 'Sam', 'property_type': 'townhouse', 'price': '375', 'minimum_nights': '3', 'maximum_nights': '20'}
# {'host_name': 'Melody', 'property_type': 'home', 'price': '60', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Cathy', 'property_type': 'home', 'price': '68', 'minimum_nights': '2', 'maximum_nights': '21'}
# {'host_name': 'Abi', 'property_type': 'townhouse', 'price': '45', 'minimum_nights': '7', 'maximum_nights': '90'}
# {'host_name': 'Simon', 'property_type': 'home', 'price': '249', 'minimum_nights': '10', 'maximum_nights': '30'}
# {'host_name': 'Anders   Gabriel', 'property_type': 'rental unit', 'price': '225', 'minimum_nights': '3', 'maximum_nights': '21'}
# {'host_name': 'Helena', 'property_type': 'rental unit', 'price': '45', 'minimum_nights': '2', 'maximum_nights': '120'}
# {'host_name': 'Jennifer', 'property_type': 'rental unit', 'price': '125', 'minimum_nights': '5', 'maximum_nights': '30'}
# {'host_name': 'James', 'property_type': 'rental unit', 'price': '144', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Nyome', 'property_type': 'rental unit', 'price': '46', 'minimum_nights': '1', 'maximum_nights': '14'}
# {'host_name': 'Puc', 'property_type': 'loft', 'price': '145', 'minimum_nights': '7', 'maximum_nights': '90'}
# {'host_name': 'Chris And Renata', 'property_type': 'rental unit', 'price': '70', 'minimum_nights': '3', 'maximum_nights': '120'}
# {'host_name': 'Niki', 'property_type': 'home', 'price': '30', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Polly', 'property_type': 'townhouse', 'price': '338', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Patrizia', 'property_type': 'rental unit', 'price': '130', 'minimum_nights': '3', 'maximum_nights': '100'}
# {'host_name': 'Sam', 'property_type': 'rental unit', 'price': '210', 'minimum_nights': '5', 'maximum_nights': '365'}
# {'host_name': 'Pierre', 'property_type': 'condo', 'price': '45', 'minimum_nights': '2', 'maximum_nights': '28'}
# {'host_name': 'Tooba', 'property_type': 'cottage', 'price': '50', 'minimum_nights': '2', 'maximum_nights': '7'}
# {'host_name': 'Zain', 'property_type': 'rental unit', 'price': '120', 'minimum_nights': '3', 'maximum_nights': '30'}
# {'host_name': 'Michele', 'property_type': 'home', 'price': '61', 'minimum_nights': '1', 'maximum_nights': '30'}
# {'host_name': 'Ali', 'property_type': 'rental unit', 'price': '115', 'minimum_nights': '3', 'maximum_nights': '31'}
# {'host_name': 'Louise', 'property_type': 'rental unit', 'price': '51', 'minimum_nights': '4', 'maximum_nights': '30'}
# {'host_name': 'Seeta', 'property_type': 'condo', 'price': '120', 'minimum_nights': '7', 'maximum_nights': '1125'}
# {'host_name': 'Tom', 'property_type': 'rental unit', 'price': '95', 'minimum_nights': '3', 'maximum_nights': '120'}
# {'host_name': 'Annamaria', 'property_type': 'rental unit', 'price': '100', 'minimum_nights': '6', 'maximum_nights': '28'}
# {'host_name': 'Mick', 'property_type': 'townhouse', 'price': '57', 'minimum_nights': '75', 'maximum_nights': '1000'}
# {'host_name': 'Sybille', 'property_type': 'townhouse', 'price': '131', 'minimum_nights': '4', 'maximum_nights': '1124'}
# {'host_name': 'Claudia', 'property_type': 'rental unit', 'price': '75', 'minimum_nights': '7', 'maximum_nights': '365'}
# {'host_name': 'Carla', 'property_type': 'loft', 'price': '45', 'minimum_nights': '7', 'maximum_nights': '30'}
# {'host_name': 'Sarah', 'property_type': 'home', 'price': '45', 'minimum_nights': '2', 'maximum_nights': '14'}
# {'host_name': 'Liz', 'property_type': 'rental unit', 'price': '55', 'minimum_nights': '5', 'maximum_nights': '180'}
# {'host_name': 'Shazia', 'property_type': 'rental unit', 'price': '47', 'minimum_nights': '2', 'maximum_nights': '365'}
# {'host_name': 'Debbie', 'property_type': 'rental unit', 'price': '45', 'minimum_nights': '28', 'maximum_nights': '90'}
# {'host_name': 'Jamie', 'property_type': 'rental unit', 'price': '111', 'minimum_nights': '90', 'maximum_nights': '365'}
# {'host_name': 'Sally', 'property_type': 'rental unit', 'price': '156', 'minimum_nights': '4', 'maximum_nights': '30'}
# {'host_name': 'Cathy', 'property_type': 'rental unit', 'price': '106', 'minimum_nights': '2', 'maximum_nights': '99'}
# {'host_name': 'AnnM', 'property_type': 'rental unit', 'price': '38', 'minimum_nights': '5', 'maximum_nights': '70'}
# {'host_name': 'Giorgio', 'property_type': 'rental unit', 'price': '95', 'minimum_nights': '90', 'maximum_nights': '1125'}
# {'host_name': 'Barry', 'property_type': 'rental unit', 'price': '85', 'minimum_nights': '14', 'maximum_nights': '60'}
# {'host_name': 'Stan And Monica', 'property_type': 'home', 'price': '45', 'minimum_nights': '5', 'maximum_nights': '90'}
# {'host_name': 'Tal   Des', 'property_type': 'home', 'price': '110', 'minimum_nights': '29', 'maximum_nights': '60'}
# {'host_name': 'Joelle', 'property_type': 'home', 'price': '50', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Adam', 'property_type': 'home', 'price': '149', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Gerry', 'property_type': 'rental unit', 'price': '55', 'minimum_nights': '2', 'maximum_nights': '6'}
# {'host_name': 'Louisa', 'property_type': 'home', 'price': '329', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Pedro', 'property_type': 'rental unit', 'price': '77', 'minimum_nights': '10', 'maximum_nights': '250'}
# {'host_name': 'Dick And Bob', 'property_type': 'townhouse', 'price': '40', 'minimum_nights': '1', 'maximum_nights': '7'}
# {'host_name': 'Jenny', 'property_type': 'rental unit', 'price': '85', 'minimum_nights': '4', 'maximum_nights': '150'}
# {'host_name': 'Raminta', 'property_type': 'condo', 'price': '119', 'minimum_nights': '5', 'maximum_nights': '20'}
# {'host_name': 'Laura', 'property_type': 'rental unit', 'price': '48', 'minimum_nights': '5', 'maximum_nights': '62'}
# {'host_name': 'Clare Frances', 'property_type': 'rental unit', 'price': '140', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Vicky', 'property_type': 'home', 'price': '51', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Roddy', 'property_type': 'rental unit', 'price': '119', 'minimum_nights': '3', 'maximum_nights': '30'}
# {'host_name': 'Rob   Emiko', 'property_type': 'townhouse', 'price': '62', 'minimum_nights': '4', 'maximum_nights': '90'}
# {'host_name': 'Wendy', 'property_type': 'rental unit', 'price': '50', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Benjamin', 'property_type': 'loft', 'price': '139', 'minimum_nights': '2', 'maximum_nights': '60'}
# {'host_name': 'Ivona', 'property_type': 'condo', 'price': '36', 'minimum_nights': '4', 'maximum_nights': '600'}
# {'host_name': 'Jesse', 'property_type': 'rental unit', 'price': '100', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Ewan', 'property_type': 'rental unit', 'price': '185', 'minimum_nights': '14', 'maximum_nights': '1125'}
# {'host_name': 'Paul', 'property_type': 'rental unit', 'price': '199', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Nikita', 'property_type': 'condo', 'price': '79', 'minimum_nights': '1', 'maximum_nights': '5'}
# {'host_name': 'Adam   Julia', 'property_type': 'townhouse', 'price': '44', 'minimum_nights': '2', 'maximum_nights': '65'}
# {'host_name': 'Vivien', 'property_type': 'home', 'price': '27', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Alina', 'property_type': 'townhouse', 'price': '59', 'minimum_nights': '1', 'maximum_nights': '28'}
# {'host_name': 'Gordon', 'property_type': 'townhouse', 'price': '65', 'minimum_nights': '3', 'maximum_nights': '8'}
# {'host_name': 'Ozzy', 'property_type': 'rental unit', 'price': '90', 'minimum_nights': '30', 'maximum_nights': '1125'}
# {'host_name': 'Toral', 'property_type': 'rental unit', 'price': '105', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Russell', 'property_type': 'rental unit', 'price': '165', 'minimum_nights': '7', 'maximum_nights': '30'}
# {'host_name': 'Peter', 'property_type': 'rental unit', 'price': '141', 'minimum_nights': '3', 'maximum_nights': '100'}
# {'host_name': 'Lydia', 'property_type': 'townhouse', 'price': '85', 'minimum_nights': '2', 'maximum_nights': '7'}
# {'host_name': 'Anna', 'property_type': 'rental unit', 'price': '175', 'minimum_nights': '5', 'maximum_nights': '14'}
# {'host_name': 'Julia', 'property_type': 'condo', 'price': '88', 'minimum_nights': '7', 'maximum_nights': '180'}
# {'host_name': 'Monika', 'property_type': 'rental unit', 'price': '37', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Diego', 'property_type': 'rental unit', 'price': '136', 'minimum_nights': '3', 'maximum_nights': '60'}
# {'host_name': 'Robin', 'property_type': 'rental unit', 'price': '214', 'minimum_nights': '18', 'maximum_nights': '180'}
# {'host_name': 'Stefano   Maria', 'property_type': 'rental unit', 'price': '118', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Annika', 'property_type': 'rental unit', 'price': '183', 'minimum_nights': '14', 'maximum_nights': '90'}
# {'host_name': 'Musa', 'property_type': 'rental unit', 'price': '79', 'minimum_nights': '1', 'maximum_nights': '3'}
# {'host_name': 'Clem', 'property_type': 'home', 'price': '375', 'minimum_nights': '4', 'maximum_nights': '7'}
# {'host_name': 'Mike', 'property_type': 'rental unit', 'price': '100', 'minimum_nights': '10', 'maximum_nights': '60'}
# {'host_name': 'Carolyn', 'property_type': 'rental unit', 'price': '145', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Emma', 'property_type': 'rental unit', 'price': '45', 'minimum_nights': '1', 'maximum_nights': '7'}
# {'host_name': 'John', 'property_type': 'home', 'price': '46', 'minimum_nights': '4', 'maximum_nights': '365'}
# {'host_name': 'Anna', 'property_type': 'townhouse', 'price': '27', 'minimum_nights': '2', 'maximum_nights': '14'}
# {'host_name': 'Gareth', 'property_type': 'rental unit', 'price': '99', 'minimum_nights': '5', 'maximum_nights': '365'}
# {'host_name': 'Martin', 'property_type': 'rental unit', 'price': '148', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Rose', 'property_type': 'condo', 'price': '75', 'minimum_nights': '2', 'maximum_nights': '93'}
# {'host_name': 'Nic', 'property_type': 'loft', 'price': '200', 'minimum_nights': '14', 'maximum_nights': '1125'}
# {'host_name': 'Jens', 'property_type': 'rental unit', 'price': '209', 'minimum_nights': '2', 'maximum_nights': '365'}
# {'host_name': 'Bianca', 'property_type': 'rental unit', 'price': '145', 'minimum_nights': '2', 'maximum_nights': '4'}
# {'host_name': 'Margaret', 'property_type': 'townhouse', 'price': '60', 'minimum_nights': '2', 'maximum_nights': '45'}
# {'host_name': 'Jane', 'property_type': 'rental unit', 'price': '130', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Lorna And Anders', 'property_type': 'rental unit', 'price': '70', 'minimum_nights': '5', 'maximum_nights': '14'}
# {'host_name': 'Paul', 'property_type': 'rental unit', 'price': '150', 'minimum_nights': '90', 'maximum_nights': '1125'}
# {'host_name': 'Grant', 'property_type': 'rental unit', 'price': '299', 'minimum_nights': '3', 'maximum_nights': '180'}
# {'host_name': 'Grant', 'property_type': 'rental unit', 'price': '150', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Caroline', 'property_type': 'rental unit', 'price': '82', 'minimum_nights': '21', 'maximum_nights': '365'}
# {'host_name': 'Consuela', 'property_type': 'condo', 'price': '55', 'minimum_nights': '7', 'maximum_nights': '365'}
# {'host_name': 'Karen', 'property_type': 'rental unit', 'price': '76', 'minimum_nights': '7', 'maximum_nights': '99'}
# {'host_name': 'Paul And Victoria', 'property_type': 'condo', 'price': '110', 'minimum_nights': '5', 'maximum_nights': '90'}
# {'host_name': 'Zac', 'property_type': 'rental unit', 'price': '125', 'minimum_nights': '28', 'maximum_nights': '365'}
# {'host_name': 'Sohin', 'property_type': 'rental unit', 'price': '325', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Mary', 'property_type': 'home', 'price': '39', 'minimum_nights': '3', 'maximum_nights': '10'}
# {'host_name': 'Tara', 'property_type': 'home', 'price': '95', 'minimum_nights': '6', 'maximum_nights': '45'}
# {'host_name': 'Hayley', 'property_type': 'rental unit', 'price': '96', 'minimum_nights': '3', 'maximum_nights': '133'}
# {'host_name': 'Abigail', 'property_type': 'rental unit', 'price': '80', 'minimum_nights': '1', 'maximum_nights': '5'}
# {'host_name': 'Kush', 'property_type': 'rental unit', 'price': '156', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Geoffrey And Vicky', 'property_type': 'rental unit', 'price': '129', 'minimum_nights': '180', 'maximum_nights': '1125'}
# {'host_name': 'Taisha', 'property_type': 'rental unit', 'price': '899', 'minimum_nights': '3', 'maximum_nights': '14'}
# {'host_name': 'Katy', 'property_type': 'rental unit', 'price': '121', 'minimum_nights': '5', 'maximum_nights': '60'}
# {'host_name': 'Stephanie', 'property_type': 'home', 'price': '200', 'minimum_nights': '5', 'maximum_nights': '20'}
# {'host_name': 'Ben', 'property_type': 'loft', 'price': '150', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Lucy', 'property_type': 'rental unit', 'price': '77', 'minimum_nights': '3', 'maximum_nights': '5'}
# {'host_name': 'Tibu', 'property_type': 'rental unit', 'price': '106', 'minimum_nights': '2', 'maximum_nights': '21'}
# {'host_name': 'Gregory', 'property_type': 'rental unit', 'price': '53', 'minimum_nights': '2', 'maximum_nights': '180'}
# {'host_name': 'Julia', 'property_type': 'rental unit', 'price': '30', 'minimum_nights': '7', 'maximum_nights': '200'}
# {'host_name': 'Kiki', 'property_type': 'rental unit', 'price': '60', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Katy', 'property_type': 'home', 'price': '30', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Miranda', 'property_type': 'rental unit', 'price': '56', 'minimum_nights': '2', 'maximum_nights': '330'}
# {'host_name': 'Mike', 'property_type': 'rental unit', 'price': '61', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Sue', 'property_type': 'townhouse', 'price': '68', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Lorraine', 'property_type': 'loft', 'price': '46', 'minimum_nights': '1', 'maximum_nights': '300'}
# {'host_name': 'Flora', 'property_type': 'townhouse', 'price': '160', 'minimum_nights': '3', 'maximum_nights': '365'}
# {'host_name': 'Tiziana', 'property_type': 'townhouse', 'price': '26', 'minimum_nights': '10', 'maximum_nights': '1125'}
# {'host_name': 'Barry', 'property_type': 'rental unit', 'price': '149', 'minimum_nights': '2', 'maximum_nights': '31'}
# {'host_name': 'Rajesh', 'property_type': 'rental unit', 'price': '110', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Noah', 'property_type': 'rental unit', 'price': '151', 'minimum_nights': '7', 'maximum_nights': '14'}
# {'host_name': 'Charlotte', 'property_type': 'rental unit', 'price': '73', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Zara', 'property_type': 'rental unit', 'price': '146', 'minimum_nights': '5', 'maximum_nights': '30'}
# {'host_name': 'Monica', 'property_type': 'townhouse', 'price': '45', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Gail', 'property_type': 'rental unit', 'price': '65', 'minimum_nights': '3', 'maximum_nights': '10'}
# {'host_name': 'Anna', 'property_type': 'rental unit', 'price': '20', 'minimum_nights': '7', 'maximum_nights': '1125'}
# {'host_name': 'Amaia', 'property_type': 'rental unit', 'price': '70', 'minimum_nights': '7', 'maximum_nights': '1125'}
# {'host_name': 'Kate', 'property_type': 'rental unit', 'price': '76', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Barrie', 'property_type': 'rental unit', 'price': '229', 'minimum_nights': '4', 'maximum_nights': '125'}
# {'host_name': 'Stanley', 'property_type': 'rental unit', 'price': '110', 'minimum_nights': '14', 'maximum_nights': '1125'}
# {'host_name': 'Leena', 'property_type': 'home', 'price': '62', 'minimum_nights': '7', 'maximum_nights': '1125'}
# {'host_name': 'Georgia', 'property_type': 'guest suite', 'price': '90', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Celi', 'property_type': 'home', 'price': '95', 'minimum_nights': '2', 'maximum_nights': '365'}
# {'host_name': 'Sarah', 'property_type': 'condo', 'price': '100', 'minimum_nights': '2', 'maximum_nights': '365'}
# {'host_name': 'Zvonko   Marija', 'property_type': 'rental unit', 'price': '89', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Stefano', 'property_type': 'rental unit', 'price': '120', 'minimum_nights': '7', 'maximum_nights': '20'}
# {'host_name': 'Andonis', 'property_type': 'home', 'price': '50', 'minimum_nights': '2', 'maximum_nights': '60'}
# {'host_name': 'Ruby', 'property_type': 'home', 'price': '96', 'minimum_nights': '10', 'maximum_nights': '1125'}
# {'host_name': 'Biljana', 'property_type': 'condo', 'price': '47', 'minimum_nights': '2', 'maximum_nights': '50'}
# {'host_name': 'Mette', 'property_type': 'rental unit', 'price': '150', 'minimum_nights': '6', 'maximum_nights': '20'}
# {'host_name': 'Paul', 'property_type': 'rental unit', 'price': '55', 'minimum_nights': '2', 'maximum_nights': '14'}
# {'host_name': 'Steve', 'property_type': 'home', 'price': '42', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Sana', 'property_type': 'rental unit', 'price': '153', 'minimum_nights': '3', 'maximum_nights': '35'}
# {'host_name': 'Hugh', 'property_type': 'cottage', 'price': '295', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Helen', 'property_type': 'home', 'price': '55', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Petra', 'property_type': 'rental unit', 'price': '320', 'minimum_nights': '3', 'maximum_nights': '28'}
# {'host_name': 'Tete', 'property_type': 'condo', 'price': '76', 'minimum_nights': '4', 'maximum_nights': '60'}
# {'host_name': 'Anna', 'property_type': 'condo', 'price': '80', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Susan', 'property_type': 'condo', 'price': '78', 'minimum_nights': '1', 'maximum_nights': '10'}
# {'host_name': 'Br', 'property_type': 'townhouse', 'price': '77', 'minimum_nights': '6', 'maximum_nights': '1125'}
# {'host_name': 'Paul', 'property_type': 'rental unit', 'price': '130', 'minimum_nights': '3', 'maximum_nights': '365'}
# {'host_name': 'Robert', 'property_type': 'condo', 'price': '159', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Tony', 'property_type': 'rental unit', 'price': '32', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Lulu', 'property_type': 'condo', 'price': '95', 'minimum_nights': '7', 'maximum_nights': '30'}
# {'host_name': 'Siobh n', 'property_type': 'rental unit', 'price': '73', 'minimum_nights': '5', 'maximum_nights': '14'}
# {'host_name': 'Jerome', 'property_type': 'home', 'price': '300', 'minimum_nights': '5', 'maximum_nights': '90'}
# {'host_name': 'Patricia', 'property_type': 'rental unit', 'price': '135', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Tom', 'property_type': 'condo', 'price': '117', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Tulio', 'property_type': 'rental unit', 'price': '110', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Stefano', 'property_type': 'rental unit', 'price': '52', 'minimum_nights': '7', 'maximum_nights': '1125'}
# {'host_name': 'Alison', 'property_type': 'townhouse', 'price': '70', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Martha', 'property_type': 'home', 'price': '25', 'minimum_nights': '7', 'maximum_nights': '365'}
# {'host_name': 'Jane', 'property_type': 'home', 'price': '53', 'minimum_nights': '1', 'maximum_nights': '30'}
# {'host_name': 'Ewa', 'property_type': 'rental unit', 'price': '124', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Giuseppe', 'property_type': 'rental unit', 'price': '264', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Ben', 'property_type': 'rental unit', 'price': '141', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Benedict', 'property_type': 'rental unit', 'price': '70', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Bronwyn', 'property_type': 'condo', 'price': '159', 'minimum_nights': '3', 'maximum_nights': '80'}
# {'host_name': 'Igor', 'property_type': 'condo', 'price': '166', 'minimum_nights': '2', 'maximum_nights': '365'}
# {'host_name': 'Anastasios', 'property_type': 'condo', 'price': '123', 'minimum_nights': '3', 'maximum_nights': '6'}
# {'host_name': 'Patricia', 'property_type': 'rental unit', 'price': '63', 'minimum_nights': '2', 'maximum_nights': '14'}
# {'host_name': 'Duska', 'property_type': 'home', 'price': '180', 'minimum_nights': '7', 'maximum_nights': '21'}
# {'host_name': 'Polly', 'property_type': 'rental unit', 'price': '230', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Tony', 'property_type': 'condo', 'price': '60', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Sophie', 'property_type': 'guest suite', 'price': '81', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Gina', 'property_type': 'townhouse', 'price': '69', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Nada', 'property_type': 'rental unit', 'price': '74', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Roni  William And Baxter', 'property_type': 'condo', 'price': '300', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Edwin', 'property_type': 'rental unit', 'price': '190', 'minimum_nights': '300', 'maximum_nights': '730'}
# {'host_name': 'Tania', 'property_type': 'rental unit', 'price': '92', 'minimum_nights': '3', 'maximum_nights': '14'}
# {'host_name': 'Gemma', 'property_type': 'home', 'price': '43', 'minimum_nights': '1', 'maximum_nights': '800'}
# {'host_name': 'Audrey', 'property_type': 'home', 'price': '92', 'minimum_nights': '1', 'maximum_nights': '14'}
# {'host_name': 'Stephen', 'property_type': 'condo', 'price': '165', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Amit', 'property_type': 'rental unit', 'price': '122', 'minimum_nights': '3', 'maximum_nights': '45'}
# {'host_name': 'Rachel', 'property_type': 'condo', 'price': '149', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Linda', 'property_type': 'rental unit', 'price': '66', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Helen', 'property_type': 'rental unit', 'price': '150', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Pilar', 'property_type': 'rental unit', 'price': '48', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Chris', 'property_type': 'townhouse', 'price': '42', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Charles', 'property_type': 'condo', 'price': '270', 'minimum_nights': '2', 'maximum_nights': '7'}
# {'host_name': 'Phyllis', 'property_type': 'condo', 'price': '137', 'minimum_nights': '3', 'maximum_nights': '28'}
# {'host_name': 'Tatjana', 'property_type': 'rental unit', 'price': '55', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'David', 'property_type': 'home', 'price': '175', 'minimum_nights': '10', 'maximum_nights': '21'}
# {'host_name': 'Lisa', 'property_type': 'rental unit', 'price': '88', 'minimum_nights': '90', 'maximum_nights': '1125'}
# {'host_name': 'Edmund', 'property_type': 'condo', 'price': '182', 'minimum_nights': '1', 'maximum_nights': '15'}
# {'host_name': 'Giuseppina', 'property_type': 'rental unit', 'price': '160', 'minimum_nights': '30', 'maximum_nights': '70'}
# {'host_name': 'Nicole', 'property_type': 'rental unit', 'price': '185', 'minimum_nights': '3', 'maximum_nights': '150'}
# {'host_name': 'Alison', 'property_type': 'home', 'price': '24', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Massimo', 'property_type': 'rental unit', 'price': '140', 'minimum_nights': '5', 'maximum_nights': '10'}
# {'host_name': 'Louisa', 'property_type': 'townhouse', 'price': '282', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Max', 'property_type': 'rental unit', 'price': '80', 'minimum_nights': '3', 'maximum_nights': '30'}
# {'host_name': 'Ese', 'property_type': 'rental unit', 'price': '50', 'minimum_nights': '5', 'maximum_nights': '60'}
# {'host_name': 'David', 'property_type': 'rental unit', 'price': '185', 'minimum_nights': '2', 'maximum_nights': '90'}
# {'host_name': 'Ella', 'property_type': 'rental unit', 'price': '190', 'minimum_nights': '3', 'maximum_nights': '12'}
# {'host_name': 'Helen', 'property_type': 'home', 'price': '195', 'minimum_nights': '6', 'maximum_nights': '21'}
# {'host_name': 'Joanna', 'property_type': 'condo', 'price': '55', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Graham', 'property_type': 'home', 'price': '86', 'minimum_nights': '2', 'maximum_nights': '30'}
# {'host_name': 'Anat', 'property_type': 'rental unit', 'price': '142', 'minimum_nights': '2', 'maximum_nights': '150'}
# {'host_name': 'Maureen', 'property_type': 'rental unit', 'price': '196', 'minimum_nights': '6', 'maximum_nights': '1125'}
# {'host_name': 'Ipek', 'property_type': 'rental unit', 'price': '80', 'minimum_nights': '160', 'maximum_nights': '1125'}
# {'host_name': 'Rosi', 'property_type': 'rental unit', 'price': '50', 'minimum_nights': '2', 'maximum_nights': '15'}
# {'host_name': 'Jenny', 'property_type': 'rental unit', 'price': '275', 'minimum_nights': '5', 'maximum_nights': '1125'}
# {'host_name': 'Alex', 'property_type': 'home', 'price': '99', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Soner', 'property_type': 'home', 'price': '245', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Sophie', 'property_type': 'rental unit', 'price': '129', 'minimum_nights': '2', 'maximum_nights': '1125'}
# {'host_name': 'Tess', 'property_type': 'rental unit', 'price': '165', 'minimum_nights': '4', 'maximum_nights': '1125'}
# {'host_name': 'Adam', 'property_type': 'home', 'price': '50', 'minimum_nights': '2', 'maximum_nights': '7'}
# {'host_name': 'Oksana', 'property_type': 'rental unit', 'price': '90', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Robert', 'property_type': 'condo', 'price': '40', 'minimum_nights': '15', 'maximum_nights': '1125'}
# {'host_name': 'Gabriel', 'property_type': 'rental unit', 'price': '38', 'minimum_nights': '2', 'maximum_nights': '100'}
# {'host_name': 'Sophie', 'property_type': 'rental unit', 'price': '130', 'minimum_nights': '3', 'maximum_nights': '365'}
# {'host_name': 'Mar', 'property_type': 'townhouse', 'price': '220', 'minimum_nights': '2', 'maximum_nights': '20'}
# {'host_name': 'Chris', 'property_type': 'condo', 'price': '150', 'minimum_nights': '5', 'maximum_nights': '100'}
# {'host_name': 'Julia', 'property_type': 'rental unit', 'price': '110', 'minimum_nights': '3', 'maximum_nights': '1125'}
# {'host_name': 'Janis M D ', 'property_type': 'home', 'price': '80', 'minimum_nights': '1', 'maximum_nights': '1125'}
# {'host_name': 'Alastair', 'property_type': 'condo', 'price': '160', 'minimum_nights': '5', 'maximum_nights': '16'}
# {'host_name': 'Maria', 'property_type': 'rental unit', 'price': '103', 'minimum_nights': '2', 'maximum_nights': '16'}
# {'host_name': 'Maggie', 'property_type': 'home', 'price': '35', 'minimum_nights': '5', 'maximum_nights': '30'}
# {'host_name': 'Claire', 'property_type': 'rental unit', 'price': '125', 'minimum_nights': '2', 'maximum_nights': '20'}
# {'host_name': 'Catherine', 'property_type': 'rental unit', 'price': '120', 'minimum_nights': '4', 'maximum_nights': '365'}
# {'host_name': 'Alistair', 'property_type': 'rental unit', 'price': '100', 'minimum_nights': '4', 'maximum_nights': '90'}
# {'host_name': 'Sarah', 'property_type': 'rental unit', 'price': '80', 'minimum_nights': '7', 'maximum_nights': '90'}
# {'host_name': 'Beychu', 'property_type': 'rental unit', 'price': '100', 'minimum_nights': '2', 'maximum_nights': '15'}
# ...
#   'amenities': '["Oven", "Hair dryer", "Private entrance", "Hangers", "Dishes and silverware", "Essentials", "Patio or balcony", "Shampoo", "Cooking basics", "Bed linens", "Bathtub", "Wifi", "Heating", "Dishwasher", "Backyard", "Long term stays allowed", "TV", "Microwave", "Refrigerator", "Iron", "Kitchen", "Stove", "Hot water", "Washer", "Smoke alarm", "Dryer", "Lockbox"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '92%',
#   'amenities': '["Essentials", "Wifi", "Coffee maker", "Free dryer \\u2013 In unit", "Hot water", "Long term stays allowed", "Shampoo", "TV", "Host greets you", "Refrigerator", "Smoke alarm", "Hair dryer", "Free washer \\u2013 In unit", "EV charger", "Iron", "Carbon monoxide alarm", "Kitchen", "Heating", "Lock on bed and breakfastroom door", "Dishes and silverware"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '75%',
#   'amenities': '["Oven", "Hair dryer", "Hangers", "Dishes and silverware", "Essentials", "Shampoo", "TV with standard cable", "Cooking basics", "Bed linens", "Bathtub", "Wifi", "Heating", "Coffee maker", "Dishwasher", "Backyard", "Long term stays allowed", "Microwave", "Refrigerator", "Iron", "Kitchen", "BBQ grill", "Stove", "Hot water", "Washer", "Paid parking off premises", "Smoke alarm", "Dryer", "Lockbox", "Cable TV"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Extra pillows and blankets", "Oven", "Fire extinguisher", "Hair dryer", "Clothing storage: dresser", "Wine glasses", "Dining table", "Hangers", "Cleaning products", "Dishes and silverware", "Essentials", "Patio or balcony", "Shampoo", "Cooking basics", "Single level home", "Bed linens", "Carbon monoxide alarm", "Shower gel", "Bathtub", "Heating", "Wifi", "Coffee maker", "Free dryer \\u2013 In unit", "Long term stays allowed", "Hot water kettle", "Sound system with Bluetooth and aux", "Microwave", "Refrigerator", "Iron", "Body soap", "Drying rack for clothing", "Kitchen", "Stove", "Conditioner", "Dedicated workspace", "Hot water", "Washer", "Smoke alarm", "Freezer"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Extra pillows and blankets", "First aid kit", "Oven", "50\\" HDTV with Amazon Prime Video, Apple TV, Netflix, standard cable", "Fire extinguisher", "Mini fridge", "Hair dryer", "Wine glasses", "Dining table", "Private entrance", "Hangers", "Cleaning products", "Dishes and silverware", "Luggage dropoff allowed", "Essentials", "Shampoo", "Cooking basics", "Bed linens", "Clothing storage: dresser and closet", "Carbon monoxide alarm", "Bathtub", "Shower gel", "Heating", "Wifi", "Coffee maker", "Free dryer \\u2013 In unit", "Dishwasher", "Long term stays allowed", "Hot water kettle", "Microwave", "Portable fans", "Refrigerator", "Room-darkening shades", "Private patio or balcony", "Iron", "Body soap", "Drying rack for clothing", "Kitchen", "Stove", "Toaster", "Conditioner", "Dedicated workspace", "Hot water", "Shared gym in building", "Paid parking off premises", "Smoke alarm", "Lockbox", "Free washer \\u2013 In unit", "Ethernet connection", "Portable air conditioning", "Cable TV", "Freezer"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '95%',
#   'amenities': '["Oven", "Hair dryer", "Hangers", "Dishes and silverware", "Essentials", "Shampoo", "Cooking basics", "Bed linens", "Paid parking on premises", "Carbon monoxide alarm", "Bathtub", "Heating", "Fast wifi \\u2013 71 Mbps", "Coffee maker", "Dishwasher", "Backyard", "Long term stays allowed", "Microwave", "Refrigerator", "Private patio or balcony", "Iron", "Kitchen", "Stove", "Security cameras on property", "Dedicated workspace", "Hot water", "Washer", "Paid parking off premises", "Smoke alarm", "Lockbox"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Essentials", "Wifi", "Washer", "Long term stays allowed", "Shampoo", "TV", "Fire extinguisher", "Smoke alarm", "Hair dryer", "Lockbox", "Private entrance", "Iron", "Dryer", "Hangers", "Kitchen", "Heating", "Dishes and silverware"]',
#   'instant_bookable': 'TRUE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Oven", "Fire extinguisher", "Hair dryer", "Private entrance", "Hangers", "Dishes and silverware", "Essentials", "Patio or balcony", "Shampoo", "TV with standard cable", "Free street parking", "Cooking basics", "Bed linens", "Carbon monoxide alarm", "Shower gel", "Wifi", "Heating", "Coffee maker", "Dishwasher", "Long term stays allowed", "Host greets you", "Microwave", "Refrigerator", "Iron", "Kitchen", "Stove", "Hot water", "Washer", "Smoke alarm", "Dryer", "Cable TV"]',
#   'instant_bookable': 'TRUE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["First aid kit", "Oven", "Hair dryer", "Hangers", "Dishes and silverware", "Essentials", "Free street parking", "Cooking basics", "Bed linens", "Carbon monoxide alarm", "Wifi", "Heating", "Dishwasher", "Long term stays allowed", "TV", "Refrigerator", "Private patio or balcony", "Iron", "Kitchen", "Stove", "Hot water", "Washer", "Elevator", "Smoke alarm", "Dryer"]',
#   'instant_bookable': 'TRUE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Hair dryer", "32\\" HDTV with Netflix", "Wine glasses", "Dining table", "Private entrance", "Hangers", "Cleaning products", "Dishes and silverware", "Luggage dropoff allowed", "Essentials", "Fast wifi \\u2013 58 Mbps", "Stainless steel oven", "Cooking basics", "Bed linens", "Bathtub", "Heating", "Coffee maker", "Dishwasher", "Hot water kettle", "Microwave", "Portable fans", "Refrigerator", "Iron", "Body soap", "Drying rack for clothing", "Kitchen", "Toaster", "Free residential garage on premises \\u2013 1 space", "Hot water", "Washer", "Clothing storage: closet and dresser", "Elevator", "Smoke alarm", "Freezer"]',
#   'instant_bookable': 'TRUE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["First aid kit", "Fire extinguisher", "Keurig  stainless steel oven", "Wine glasses", "Fast wifi \\u2013 79 Mbps", "Hangers", "Cleaning products", "Dishes and silverware", "Luggage dropoff allowed", "Essentials", "Shampoo", "Baking sheet", "Cooking basics", "Bed linens", "Clothing storage: dresser and closet", "Carbon monoxide alarm", "Shower gel", "Free driveway parking on premises \\u2013 1 space", "Central heating", "Coffee maker", "Free dryer \\u2013 In unit", "Dishwasher", "Backyard", "Hot water kettle", "Microwave", "Portable fans", "Refrigerator", "Host greets you", "Room-darkening shades", "Outdoor dining area", "Private patio or balcony", "Iron", "Body soap", "Drying rack for clothing", "Bluetooth sound system", "Kitchen", "Stove", "Toaster", "Conditioner", "Dedicated workspace", "Hot water", "Board games", "Smoke alarm", "HDTV with Amazon Prime Video, Chromecast, Roku, Netflix", "Free washer \\u2013 In unit", "Laundromat nearby", "Outdoor furniture", "Freezer"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '93%',
#   'amenities': '["Oven", "Hair dryer", "Private entrance", "Hangers", "Dishes and silverware", "Essentials", "Patio or balcony", "Shampoo", "Bed linens", "Carbon monoxide alarm", "Wifi", "Heating", "Dishwasher", "Backyard", "Long term stays allowed", "Refrigerator", "Iron", "Kitchen", "Paid street parking off premises", "Hot water", "Washer", "Smoke alarm", "Ethernet connection", "Dryer"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '90%',
#   'amenities': '["Essentials", "Wifi", "Washer", "Long term stays allowed", "Shampoo", "TV", "Microwave", "Refrigerator", "Smoke alarm", "Hair dryer", "Iron", "Carbon monoxide alarm", "Hangers", "Kitchen", "Heating", "Toaster"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '82%',
#   'amenities': '["Essentials", "First aid kit", "Dedicated workspace", "Shampoo", "Paid washer \\u2013 In unit", "Smoke alarm", "Clothing storage", "Iron", "Hangers", "Kitchen", "Central heating", "Wifi", "Dishes and silverware"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '95%',
#   'amenities': '["Extra pillows and blankets", "Record player", "First aid kit", "Oven", "Radiant heating", "Hair dryer", "Wine glasses", "Dining table", "Hangers", "Piano", "Cleaning products", "Rice maker", "Dishes and silverware", "Luggage dropoff allowed", "Essentials", "Shampoo", "Shared sauna", "Clothing storage: closet", "Cooking basics", "Sound system", "Bed linens", "Carbon monoxide alarm", "Shower gel", "Wifi", "Dishwasher", "Long term stays allowed", "TV", "Hot water kettle", "Microwave", "Refrigerator", "Host greets you", "Room-darkening shades", "Outdoor dining area", "Iron", "Body soap", "Drying rack for clothing", "Kitchen", "Stove", "Toaster", "Conditioner", "Paid street parking off premises", "Shared gym in building", "Hot water", "Board games", "Elevator", "Shared patio or balcony", "Smoke alarm", "Free washer \\u2013 In unit", "Laundromat nearby", "Outdoor furniture", "Freezer"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '80%',
#   'amenities': '["Oven", "Hangers", "Dishes and silverware", "Essentials", "Free street parking", "Cooking basics", "Bed linens", "Wifi", "Heating", "Coffee maker", "Dishwasher", "Long term stays allowed", "Microwave", "Refrigerator", "Iron", "Kitchen", "Stove", "Hot water", "Washer", "Paid parking off premises", "Smoke alarm", "Dryer", "Lockbox"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Dedicated workspace", "Washer", "Long term stays allowed", "TV", "BBQ grill", "Fire extinguisher", "Smoke alarm", "Carbon monoxide alarm", "Kitchen", "Wifi"]',
#   'instant_bookable': 'TRUE'},
#  {'acceptance_rate': '89%',
#   'amenities': '["First aid kit", "Oven", "Radiant heating", "Apple HomePods Bluetooth sound system", "Fire extinguisher", "Fast wifi \\u2013 358 Mbps", "49\\" HDTV with Amazon Prime Video, Apple TV, Netflix", "Hair dryer", "Dining table", "Hangers", "Cleaning products", "Dishes and silverware", "Luggage dropoff allowed", "Essentials", "Free parking on premises", "Shampoo", "Cooking basics", "Bed linens", "Pour-over coffee", "Shower gel", "Bathtub", "Coffee maker", "Dishwasher", "Hot water kettle", "Refrigerator", "Portable fans", "Room-darkening shades", "Body soap", "Drying rack for clothing", "Kitchen", "Conditioner", "Hot water", "Gas stove", "Smoke alarm", "Free washer \\u2013 In unit", "Freezer"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '77%',
#   'amenities': '["Extra pillows and blankets", "Record player", "Barbecue utensils", "Fire extinguisher", "Mini fridge", "Hair dryer", "Clothing storage: walk-in closet, closet, wardrobe, and dresser", "Wine glasses", "Dining table", "Private entrance", "Large American refrigerator", "Hangers", "Private gym in building", "Cleaning products", "Rice maker", "Dishes and silverware", "Essentials", "Stainless steel oven", "Free parking on premises", "Shampoo", "Bread maker", "Baking sheet", "Cooking basics", "Free street parking", "Bed linens", "Carbon monoxide alarm", "Bathtub", "Shower gel", "Indoor fireplace", "Central heating", "Wifi", "Coffee maker", "Dishwasher", "Long term stays allowed", "TV", "Hot water kettle", "Microwave", "Portable fans", "Room-darkening shades", "Outdoor dining area", "Private patio or balcony", "Iron", "Body soap", "Drying rack for clothing", "Kitchen", "BBQ grill", "Toaster", "Conditioner", "Dedicated workspace", "Hot water", "Washer", "Board games", "Sonos sound system with aux", "Private fenced garden or backyard", "Gas stove", "Smoke alarm", "Free dryer \\u2013 In building", "Ethernet connection", "Lockbox", "Outdoor furniture", "Freezer"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Free driveway parking on premises", "Wine glasses", "Beko refrigerator", "Dining table", "Private entrance", "Hangers", "Cleaning products", "Dishes and silverware", "Essentials", "Stainless steel oven", "HDTV with Roku, Amazon Prime Video, Apple TV, Netflix", "Cooking basics", "Bed linens", "Clothing storage: dresser and closet", "Bathtub", "Central heating", "Wifi", "Coffee maker", "Free dryer \\u2013 In unit", "Dishwasher", "Hot water kettle", "Microwave", "Shared fenced garden or backyard", "Outdoor dining area", "Iron", "Kitchen", "Drying rack for clothing", "Toaster", "Dedicated workspace", "Hot water", "Board games", "Smoke alarm", "Free washer \\u2013 In unit", "Lockbox", "Freezer"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '64%',
#   'amenities': '["Extra pillows and blankets", "First aid kit", "Oven", "Barbecue utensils", "Hair dryer", "Wine glasses", "Dining table", "Private entrance", "Hangers", "Piano", "Cleaning products", "Dishes and silverware", "Essentials", "Shampoo", "Baking sheet", "Cooking basics", "Bed linens", "Bathtub", "Shower gel", "Central heating", "Wifi", "Coffee maker", "Backyard", "Long term stays allowed", "Hot water kettle", "Microwave", "Refrigerator", "Room-darkening shades", "Outdoor dining area", "Private patio or balcony", "Iron", "Body soap", "Drying rack for clothing", "Bluetooth sound system", "Kitchen", "BBQ grill", "Stove", "Conditioner", "Dedicated workspace", "Hot water", "Washer", "Board games", "Smoke alarm", "Ethernet connection", "Lockbox", "Outdoor furniture", "Freezer"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Extra pillows and blankets", "Cleaning before checkout", "Hair dryer", "Wine glasses", "50\\" HDTV with Netflix, Roku, standard cable", "Dining table", "Private entrance", "Hangers", "Cleaning products", "Dishes and silverware", "Essentials", "Stainless steel oven", "Outdoor furniture", "Baking sheet", "Cooking basics", "Bed linens", "Carbon monoxide alarm", "Shower gel", "Heating", "Wifi", "Coffee maker", "Clothing storage: wardrobe and closet", "Long term stays allowed", "Hot water kettle", "Microwave", "Refrigerator", "Room-darkening shades", "Outdoor dining area", "Private patio or balcony", "Coconut Shower Gel body soap", "Iron", "Stainless steel electric stove", "Kitchen", "Drying rack for clothing", "Coconut Shampoo shampoo", "Toaster", "Paid street parking off premises", "Dedicated workspace", "Hot water", "Coconut Hair Conditioner conditioner", "Elevator", "Smoke alarm", "Free washer \\u2013 In unit", "Ethernet connection", "Laundromat nearby", "Lockbox", "Cable TV", "Freezer"]',
#   'instant_bookable': 'TRUE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Extra pillows and blankets", "Hair dryer", "Private entrance", "Hangers", "Luggage dropoff allowed", "Essentials", "Shampoo", "Free street parking", "Clothing storage: closet", "Single level home", "Bed linens", "Carbon monoxide alarm", "Bathtub", "Wifi", "Heating", "Long term stays allowed", "Host greets you", "Outdoor dining area", "Private patio or balcony", "Iron", "Body soap", "Dedicated workspace", "Hot water", "Private fenced garden or backyard", "Smoke alarm", "Laundromat nearby", "Lockbox", "Outdoor furniture"]',
#   'instant_bookable': 'FALSE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Wifi", "First aid kit", "Dedicated workspace", "Washer", "Backyard", "Long term stays allowed", "Smoke alarm", "Carbon monoxide alarm", "Kitchen", "Heating"]',
#   'instant_bookable': 'TRUE'},
#  {'acceptance_rate': '91%',
#   'amenities': '["Oven", "Hair dryer", "Hangers", "Cleaning products", "Dishes and silverware", "Essentials", "Free parking on premises", "Shampoo", "Clothing storage: closet", "Cooking basics", "Carbon monoxide alarm", "Shower gel", "Bathtub", "Central heating", "Wifi", "Long term stays allowed", "Microwave", "Portable fans", "Refrigerator", "Room-darkening shades", "Iron", "Body soap", "Drying rack for clothing", "Kitchen", "Conditioner", "Dedicated workspace", "Hot water", "Washer", "Smoke alarm", "Lockbox", "Freezer"]',
#   'instant_bookable': 'TRUE'},
#  {'acceptance_rate': '100%',
#   'amenities': '["Coffee maker", "First aid kit", "Free dryer \\u2013 In unit", "Dedicated workspace", "Refrigerator", "Smoke alarm", "Free washer \\u2013 In unit", "72\\" HDTV with Amazon Prime Video, Apple TV, Netflix", "Carbon monoxide alarm", "Kitchen", "Wifi"]',
#   'instant_bookable': 'TRUE'}]
